# %%
# Wheat kernel data set 
Three different varieties of wheat: Kama, Rosa and Canadian were investigated. 
Measurements of the internal kernel structure was detected using a soft X-ray technique. 
Several variables were measured:
area A, perimeter P, compactness C = 4*pi*A/P^2, length of kernel, width of kernel, asymmetry coefficient, length of kernel groove.
![close-up-crop-field-96769.jpg](attachment:close-up-crop-field-96769.jpg)

# %%
#read in dataset

# %%
import pandas as pd

# %%
data = pd.read_csv("seeds.csv")

# %%
data
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
data.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
#create a dictionary to change the type to the name of variety of wheat

# %%
types = {"Kama" : 1, "Rosa" : 2, "Canadian" : 3}

# %%
print(types)
# Out:
# {'Kama': 1, 'Rosa': 2, 'Canadian': 3}

# %% [markdown]
# how many samples for each variety of wheat are there?

# %%
data["Type"].value_counts(normalize=False)
# Out:
# 2    68
# 1    66
# 3    65
# Name: Type, dtype: int64

# %%
import seaborn as sns

# %%
graph = sns.countplot(x=data['Type'])

# %% [markdown]
# which type of wheat is larger on average?

# %%
kama = data[0:66]
kama
# Out:
#      Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0   15.26      14.84       0.8710          5.763         3.312
# 1   14.88      14.57       0.8811          5.554         3.333
# 2   14.29      14.09       0.9050          5.291         3.337
# 3   13.84      13.94       0.8955          5.324         3.379
# 4   16.14      14.99       0.9034          5.658         3.562
# ..    ...        ...          ...            ...           ...
# 61  12.78      13.57       0.8716          5.262         3.026
# 62  12.88      13.50       0.8879          5.139         3.119
# 63  14.34      14.37       0.8726          5.630         3.190
# 64  14.01      14.29       0.8625          5.609         3.158
# 65  12.73      13.75       0.8458          5.412         2.882
#
#     Asymmetry.Coeff  Kernel.Groove  Type
# 0             2.221          5.220     1
# 1             1.018          4.956     1
# 2             2.699          4.825     1
# 3             2.259          4.805     1
# ...

# %%
rosa = data[67:134]
rosa
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 67   16.84      15.67       0.8623          5.998         3.484
# 68   17.26      15.73       0.8763          5.978         3.594
# 69   19.11      16.26       0.9081          6.154         3.930
# 70   16.82      15.51       0.8786          6.017         3.486
# 71   16.77      15.62       0.8638          5.927         3.438
# ..     ...        ...          ...            ...           ...
# 129  15.56      14.89       0.8823          5.776         3.408
# 130  17.36      15.76       0.8785          6.145         3.574
# 131  15.57      15.15       0.8527          5.920         3.231
# 132  15.60      15.11       0.8580          5.832         3.286
# 133  16.23      15.18       0.8850          5.872         3.472
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 67             4.675          5.877     2
# 68             4.539          5.791     2
# 69             2.936          6.079     2
# ...

# %%
canadian = data[135:199]
canadian
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 135  13.32      13.94       0.8613          5.541         3.073
# 136  13.34      13.95       0.8620          5.389         3.074
# 137  12.22      13.32       0.8652          5.224         2.967
# 138  11.82      13.40       0.8274          5.314         2.777
# 139  11.21      13.13       0.8167          5.279         2.687
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 135            7.035          5.440     3
# 136            5.995          5.307     3
# 137            5.469          5.221     3
# ...

# %%
#area

# %%
kama['Area'].mean()
# Out:
# 14.354393939393937

# %%
rosa['Area'].mean()
# Out:
# 18.381194029850747

# %%
canadian['Area'].mean()
# Out:
# 11.862499999999999

# %%
g = sns.boxplot(data = data, 
                    x = 'Type',
                    y = "Area")
g.set_xlabel("Variety")
g.set_ylabel("Area")
g.set_title("Wheat Area")
# Out:
# Text(0.5, 1.0, 'Wheat Area')

# %%
#on average Rosa has the largest area

# %%
#perimeter

# %%
kama['Perimeter'].mean()
# Out:
# 14.306818181818178

# %%
rosa['Perimeter'].mean()
# Out:
# 16.159552238805972

# %%
canadian['Perimeter'].mean()
# Out:
# 13.245781250000002

# %%
g1 = sns.boxplot(data = data, 
                    x = 'Type',
                    y = "Perimeter")
g1.set_xlabel("Variety")
g1.set_ylabel("Perimeter")
g1.set_title("Wheat Perimeter")
# Out:
# Text(0.5, 1.0, 'Wheat Perimeter')

# %%
#on average Rosa has the longest perimeter

# %%
#kernel length

# %%
graph1 = sns.boxplot(data = data, 
                    x = 'Type',
                    y = 'Kernel.Length')
graph1.set_xlabel("Variety")
graph1.set_ylabel("Kernel Length")
graph1.set_title("Wheat Kernel Length")
# Out:
# Text(0.5, 1.0, 'Wheat Kernel Length')

# %%
#Rosa has the longest wheat kernel

# %%
#kernel width

# %%
graph2 = sns.boxplot(data = data, 
                    x = 'Type',
                    y = "Kernel.Width")
graph2.set_xlabel("Variety")
graph2.set_ylabel("Kernel Width")
graph2.set_title("Wheat Kernel Width")
# Out:
# Text(0.5, 1.0, 'Wheat Kernel Width')

# %%
#Rosa has the widest wheat kernel

# %%
#Rosa is the largest wheat variety of the three varieties tested here

# %%
#based on wheat area, perimeter, wheat kernel length and wheat kernel width.

# %% [markdown]
# Distribution plots to look at possible associations and correlations between the data

# %%
plot = sns.scatterplot(data = data, 
                      x = 'Area', 
                      y = 'Kernel.Length', 
                      hue = 'Type')
plot.set_ylabel("Kernel Length")
plot.set_title("Association between Wheat Area and Kernel Length")
# Out:
# Text(0.5, 1.0, 'Association between Wheat Area and Kernel Length')

# %%
#Positive correlation between wheat Area and Kernel Length, some evidence of clustering

# %%
plot2 = sns.scatterplot(data = data, 
                      x = 'Area', 
                      y = 'Kernel.Width', 
                      hue = 'Type')
plot2.set_ylabel("Kernel Width")
plot2.set_title("Association between Wheat Area and Kernel Width")
# Out:
# Text(0.5, 1.0, 'Association between Wheat Area and Kernel Width')

# %%
#Positive correlation between wheat Area and Kernel Width, some evidence of clustering

# %%
plot3 = sns.scatterplot(data = data, 
                      x = 'Kernel.Width', 
                      y = 'Kernel.Length', 
                      hue = 'Type')
plot3.set_ylabel("Kernel Length")
plot3.set_xlabel("Kernel Width")
plot3.set_title("Association between Kernel Length and Kernel Width")
# Out:
# Text(0.5, 1.0, 'Association between Kernel Length and Kernel Width')

# %%
#positive correlation between kernel length and kernel width, some evidence of clustering

# %%
plot4 = sns.scatterplot(data = data, 
                      x = 'Kernel.Length', 
                      y = 'Kernel.Groove', 
                      hue = 'Type')
plot4.set_xlabel("Kernel Length")
plot4.set_ylabel("Kernel Groove Length")
plot4.set_title("Association between Kernel Length and Kernel Groove Length")
# Out:
# Text(0.5, 1.0, 'Association between Kernel Length and Kernel Groove Length')

# %%
#Strong positive correlation between Kernel Length and Kernel Groove Length with evidence of clustering

# %%
plot5 = sns.scatterplot(data = data, 
                      x = 'Kernel.Width', 
                      y = 'Kernel.Groove', 
                      hue = 'Type')
plot5.set_xlabel("Kernel Width")
plot5.set_ylabel("Kernel Groove Length")
plot5.set_title("Association between Kernel Width and Kernel Groove Length")
# Out:
# Text(0.5, 1.0, 'Association between Kernel Width and Kernel Groove Length')

# %%
#no obvious correlation between kernel width and kernel groove length, some evidence of clustering

# %%
plot5 = sns.scatterplot(data = data, 
                      x = 'Compactness',
                      y = 'Kernel.Groove',
                        hue = 'Type')
plot5.set_ylabel("Kernel Groove Length")
plot5.set_title("Association between Compactness and Kernel Groove Length")
# Out:
# Text(0.5, 1.0, 'Association between Compactness and Kernel Groove Length')

# %%
#no obvious correlation between compactness and kernel groove length, some evidence of clustering

# %%
p = sns.relplot(data = data, 
                      x = 'Kernel.Length', 
                      y = 'Kernel.Width', 
                      hue = 'Compactness', 
                      style = 'Type')

# %%
#positive correlation of kernel length and kernel width, some possible clustering by type, 
#possible indirectly proportional relationship between compactness and knernel length 
#(as kernel length increases, compactness decreases)

# %%
p2 = sns.relplot(data = data, 
                      x = 'Kernel.Length', 
                      y = 'Kernel.Width', 
                      hue = 'Asymmetry.Coeff', 
                      style = 'Type')

# %%
#positive correlation between kernel length and kernel width, some possible clustering by type, 
#no evidence of effect of asymmetry coefficient

# %%
p3 = sns.relplot(data = data, 
                      x = 'Kernel.Length', 
                      y = 'Kernel.Width', 
                      hue = 'Kernel.Groove', 
                      style = 'Type')

# %%
#positive correlation between kernel length and kernel width, some possible clustering by type, 
#possible directly proportional relationship between kernel length and kernel groove length 
#(as kernel length increases so does kernel groove length)

# %%
#linear regression of area and perimeter

# %%
area = data['Area']
area
# Out:
# 0      15.26
# 1      14.88
# 2      14.29
# 3      13.84
# 4      16.14
#        ...
# 194    12.19
# 195    11.23
# 196    13.20
# 197    11.84
# 198    12.30
# Name: Area, Length: 199, dtype: float64

# %%
perm = data['Perimeter']
perm
# Out:
# 0      14.84
# 1      14.57
# 2      14.09
# 3      13.94
# 4      14.99
#        ...
# 194    13.20
# 195    12.88
# 196    13.66
# 197    13.21
# 198    13.34
# Name: Perimeter, Length: 199, dtype: float64

# %%
#create test model and values

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(area, perm, random_state=42)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.scatter(train_X, train_y, color="red", marker="o", label="train")
ax.scatter(test_X, test_y, color="blue", marker="x", label="test")
ax.legend()

# %%
#reshape data into numpy array

# %%
import numpy as np

train_X = np.array(train_X).reshape(-1, 1)
test_X = np.array(test_X).reshape(-1, 1)

# %%
#fit linear regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
train_score = model.score(train_X, train_y)
print("The training score of the model is: ", train_score)
test_score = model.score(test_X, test_y)
print("The score of the model on test data is:", test_score )
# Out:
# The training score of the model is:  0.9894804594635328
# The score of the model on test data is: 0.9870671748632046

# %%
#model score is very close to 1, therefore the model is a good model

# %%
#visualise linear regression

# %%
import matplotlib.pyplot as plt

y_pred = model.predict(test_X)
plt.scatter(test_X, test_y, color='b')
plt.xlabel('Area')
plt.ylabel('Perimeter')
plt.title('Linear regression to fit Test Data')
plt.plot(test_X, y_pred, color='k')
plt.show()

# %%
#graph shows clear linear regression

# %%
#correlation analysis

# %%
corr = data.corr()
corr
# Out:
#                      Area  Perimeter  Compactness  Kernel.Length  \
# Area             1.000000   0.994437     0.609887       0.951126
# Perimeter        0.994437   1.000000     0.531841       0.972944
# Compactness      0.609887   0.531841     1.000000       0.374011
# Kernel.Length    0.951126   0.972944     0.374011       1.000000
# Kernel.Width     0.970980   0.945496     0.762167       0.862680
# Asymmetry.Coeff -0.222820  -0.211034    -0.329400      -0.169704
# Kernel.Groove    0.862727   0.889543     0.227016       0.932124
# Type            -0.340664  -0.322223    -0.539261      -0.249422
#
#                  Kernel.Width  Asymmetry.Coeff  Kernel.Groove      Type
# Area                 0.970980        -0.222820       0.862727 -0.340664
# Perimeter            0.945496        -0.211034       0.889543 -0.322223
# Compactness          0.762167        -0.329400       0.227016 -0.539261
# Kernel.Length        0.862680        -0.169704       0.932124 -0.249422
# ...

# %%
#visualise correlation

# %%
# %matplotlib inline

sns.heatmap(corr, vmin=-1.0, vmax=1.0, square=True, cmap="RdBu")
# Out:
# <AxesSubplot:>

# %%
#dark blue colour shows area and perimeter are highly correlated, 
#providing further evidence along with the linear regression score

# %%
#dark blue squares show that kernel length and kernel width are also strongly correlated

# %%
#asymmetry coefficient is negatively correlated with all variables aside from type,
#mostly strongly negatively correlated with compactness

# %%
#multi-variable scatter mix

# %%
#shows correlation of multiple variables at once

# %%
from pandas.plotting import scatter_matrix

a = scatter_matrix(data, figsize=(16, 16))

# %%
#compactness and asymmetry coefficient are weakly negatively correlated

# %%
#linear regression of compactness and Asymmetry Coefficient

# %%
comp = data['Compactness']
comp
# Out:
# 0      0.8710
# 1      0.8811
# 2      0.9050
# 3      0.8955
# 4      0.9034
#         ...
# 194    0.8783
# 195    0.8511
# 196    0.8883
# 197    0.8521
# 198    0.8684
# Name: Compactness, Length: 199, dtype: float64

# %%
asym = data['Asymmetry.Coeff']
asym
# Out:
# 0      2.221
# 1      1.018
# 2      2.699
# 3      2.259
# 4      1.355
#        ...
# 194    3.631
# 195    4.325
# 196    8.315
# 197    3.598
# 198    5.637
# Name: Asymmetry.Coeff, Length: 199, dtype: float64

# %%
#create model and test values

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(comp, asym, random_state=42)

# %%
#visualise model and test values

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.scatter(train_X, train_y, color="red", marker="o", label="train")
ax.scatter(test_X, test_y, color="blue", marker="x", label="test")
ax.legend()

# %%
#reshape data

# %%
import numpy as np

train_X = np.array(train_X).reshape(-1, 1)
test_X = np.array(test_X).reshape(-1, 1)

# %%
#fit linear regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
train_score = model.score(train_X, train_y)
print("The training score of the model is: ", train_score)
test_score = model.score(test_X, test_y)
print("The score of the model on test data is:", test_score )
# Out:
# The training score of the model is:  0.11780525608195613
# The score of the model on test data is: 0.06567626230709955

# %%
#this is a very poor model as the regression score is close 0 and not 1

# %%
#visualise model

# %%
y_pred = model.predict(test_X)
plt.scatter(test_X, test_y, color='b')
plt.xlabel('Compactness')
plt.ylabel('Asymmetry Coefficient')
plt.title('Linear fit to Test Data')
plt.plot(test_X, y_pred, color='k')
plt.show()

# %%
#this is a poor model shown by the spread of the data not being close to the regression line

# %%
corr['Compactness']
# Out:
# Area               0.609887
# Perimeter          0.531841
# Compactness        1.000000
# Kernel.Length      0.374011
# Kernel.Width       0.762167
# Asymmetry.Coeff   -0.329400
# Kernel.Groove      0.227016
# Type              -0.539261
# Name: Compactness, dtype: float64

# %%
corr['Asymmetry.Coeff']
# Out:
# Area              -0.222820
# Perimeter         -0.211034
# Compactness       -0.329400
# Kernel.Length     -0.169704
# Kernel.Width      -0.253122
# Asymmetry.Coeff    1.000000
# Kernel.Groove     -0.003349
# Type               0.573956
# Name: Asymmetry.Coeff, dtype: float64

# %%
#the model being poor is unsurprising as there was a weak negative correlation between compactness and the asymmetry coefficient 
#-0.329400
#showing a negative correlation but not a strong one

# %%
#kernel length and kernel width showed a strong positive correlation

# %%
#linear regression of kernel length and kernel width

# %%
len = data['Kernel.Length']
len
# Out:
# 0      5.763
# 1      5.554
# 2      5.291
# 3      5.324
# 4      5.658
#        ...
# 194    5.137
# 195    5.140
# 196    5.236
# 197    5.175
# 198    5.243
# Name: Kernel.Length, Length: 199, dtype: float64

# %%
wid = data['Kernel.Width']
wid
# Out:
# 0      3.312
# 1      3.333
# 2      3.337
# 3      3.379
# 4      3.562
#        ...
# 194    2.981
# 195    2.795
# 196    3.232
# 197    2.836
# 198    2.974
# Name: Kernel.Width, Length: 199, dtype: float64

# %%
#create model values

# %%
train_X, test_X, train_y, test_y = train_test_split(len, wid, random_state=42)

# %%
#visualise model

# %%
fig, ax = plt.subplots()

ax.scatter(train_X, train_y, color="red", marker="o", label="train")
ax.scatter(test_X, test_y, color="blue", marker="x", label="test")
ax.legend()

# %%
#reshape data

# %%
train_X = np.array(train_X).reshape(-1, 1)
test_X = np.array(test_X).reshape(-1, 1)

# %%
#fit linear regression

# %%
model = LinearRegression(fit_intercept=True)
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
train_score = model.score(train_X, train_y)
print("The training score of the model is: ", train_score)
test_score = model.score(test_X, test_y)
print("The score of the model on test data is:", test_score )
# Out:
# The training score of the model is:  0.7573971275781425
# The score of the model on test data is: 0.7047174562467267

# %%
#this is an okay model, as 0.7 isn't very close to 1

# %%
#visualise model

# %%
y_pred = model.predict(test_X)
plt.scatter(test_X, test_y, color='b')
plt.xlabel('Area')
plt.ylabel('Perimeter')
plt.title('Linear fit to Test Data')
plt.plot(test_X, y_pred, color='k')
plt.show()

# %%
#points are gathered around regression line

# %%
#copy dataset to carry out cluster analysis

# %%
import copy

# %%
data2 = copy.deepcopy(data)

# %%
data2.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
#K means cluster analysis

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
X = data2
Y = data2
Z = np.vstack((X,Y))

# %%
#convert to numpy float

# %%
Z = np.float32(Z)

# %%
#define criteria and apply kmeans analysis

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
ret,label,center = cv2.kmeans(Z,2,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

# %%
#seperate the data

# %%
A = Z[label.ravel()==0]
B = Z[label.ravel()==1]

# %%
#plot the data

# %%
plt.scatter(A[:,0],A[:,1])
plt.scatter(B[:,0],B[:,1],c = 'r')
plt.scatter(center[:,0],center[:,1],s = 80,c = 'y', marker = 's')
plt.xlabel('Test Data'),plt.ylabel('Z samples')
plt.show()

# %%
#shows two clusters, but the edge of the clusters are slightly overlapping

# %%
#however there are three varities or wheat, not two, therefore each variety does not belong to a seperate cluster
